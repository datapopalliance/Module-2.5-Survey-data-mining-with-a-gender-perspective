# %%
import pandas as pd
from src.cleaning_tools import convert_category_cols_to_str, drop_cols_containing_str, eliminate_null
from src.read_write_tools import read_files_in_folder, read_files_in_multiple_folders, read_files_with_multiple_tables, write_files_dpa_convention, read_xlsx_files_in_folder

# %%
pd.read_excel('sog_agg_country.xlsx')
# Out:
#              Important information about this dataset  \
# 0                                             Updated
# 1                                             Content
# 2   For additional context, methodological notes, ...
# 3                    Frequenty Asked Questions (FAQs)
# 4    How are the country-level statistics calculated?
# 5                  How should I interpret the values?
# 6                  Why aren't all countries included?
# 7   Why aren’t statistics provided for every respo...
# 8   The survey included an "Optional" section. Whe...
# 9   The survey include open-ended questions. Where...
# 10  Is this data statistically representative of t...
# 11                  Can I access the raw survey data?
# 12  Does this data include the same questions and ...
#
#                                            Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                 2020-01-01 00:00:00         NaN         NaN
# 1   This dataset contains aggregate response data ...         NaN         NaN
# 2   https://dataforgood.fb.com/docs/gendersurveyre...         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4   The country- level statistics provided reflect...         NaN         NaN
# 5   Unless otherwise indicated in the Codebook, a ...         NaN         NaN
# 6   The survey was not administered in every count...         NaN         NaN
# 7   This country-level dataset provides statistics...         NaN         NaN
# 8   In general, respondents were allowed to skip a...         NaN         NaN
# 9   Responses to open-ended questions are not incl...         NaN         NaN
# 10  No. Weights were applied to ensure this data i...         NaN         NaN
# 11  De-identified, record-level response data to m...         NaN         NaN
# 12  The questions and response options in the two ...         NaN         NaN
#
#     Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN         NaN         NaN
#
#     ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0   ...          NaN          NaN          NaN          NaN          NaN
# 1   ...          NaN          NaN          NaN          NaN          NaN
# 2   ...          NaN          NaN          NaN          NaN          NaN
# 3   ...          NaN          NaN          NaN          NaN          NaN
# 4   ...          NaN          NaN          NaN          NaN          NaN
# 5   ...          NaN          NaN          NaN          NaN          NaN
# 6   ...          NaN          NaN          NaN          NaN          NaN
# 7   ...          NaN          NaN          NaN          NaN          NaN
# 8   ...          NaN          NaN          NaN          NaN          NaN
# 9   ...          NaN          NaN          NaN          NaN          NaN
# 10  ...          NaN          NaN          NaN          NaN          NaN
# 11  ...          NaN          NaN          NaN          NaN          NaN
# 12  ...          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
#
# [13 rows x 26 columns]

# %%
pd.read_excel('sog_agg_country.xlsx')
